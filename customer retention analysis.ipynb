# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r"C:\Users\USER\Documents\customer charn.csv.xlsx")

# %%
df
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 0           NaN                      0                    3
# 1           NaN                      1                    2
# 2           NaN                      1                    2
# 3           NaN                      0                    2
# 4           NaN                      1                    2
# ..          ...                    ...                  ...
# 264         NaN                      1                    2
# 265         NaN                      1                    3
# 266         NaN                      1                    4
# 267         NaN                      1                    1
# 268         NaN                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
# ...

# %%
df1 = pd.read_excel(r"C:\Users\USER\Documents\customer charn.csv.xlsx",names=['nil','gender','age','city','pin','duration','times of purchase','internet access',
                                                                             'device','screen size','os','browser','channel','reach','time taken',
                                                                             'payoption','cart','shopping cart','web content','similar procuct','info','info procuct','navigation','processing speed',
                                                                             'user freindly web','pay method','time trust','empathy','privacy','communication','benifit','enjoyment','flexibility',
                                                                              'return policy','loyalty','quality','web quality','net benifit','trust','variety category','provision','savings',
                                                                              'patronizing','adventure','social status','gratification','role','value'])

# %%
df1
# Out:
#      nil  gender  age           city     pin  duration  times of purchase  \
# 0    NaN       0    3          Delhi  110009         5                  4
# 1    NaN       1    2          Delhi  110030         5                  5
# 2    NaN       1    2  Greater Noida  201308         4                  5
# 3    NaN       0    2        Karnal   132001         4                  1
# 4    NaN       1    2     Bangalore   530068         3                  2
# ..   ...     ...  ...            ...     ...       ...                ...
# 264  NaN       1    2          Solan  173212         2                  1
# 265  NaN       1    3      Ghaziabad  201008         2                  4
# 266  NaN       1    4     Bangalore   560010         3                  1
# 267  NaN       1    1          Solan  173229         3                  1
# 268  NaN       1    4      Ghaziabad  201009         3                  4
#
#      internet access  device  screen size  ...  trust  variety category  \
# ...

# %%
df1.drop(columns=["nil"],axis=1,inplace=True)

# %%
df1.shape
# Out:
# (269, 47)

# %%
df1.dtypes
# Out:
# gender                int64
# age                   int64
# city                 object
# pin                   int64
# duration              int64
# times of purchase     int64
# internet access       int64
# device                int64
# screen size           int64
# os                    int64
# browser               int64
# channel               int64
# reach                 int64
# time taken            int64
# payoption             int64
# cart                  int64
# shopping cart         int64
# web content           int64
# similar procuct       int64
# info                  int64
# info procuct          int64
# navigation            int64
# processing speed      int64
# user freindly web     int64
# pay method            int64
# time trust            int64
# empathy               int64
# privacy               int64
# communication         int64
# benifit               int64
# enjoyment             int64
# flexibility           int64
# return policy         int64
# ...

# %%
df1.describe()
# Out:
#            gender         age            pin    duration  times of purchase  \
# count  269.000000  269.000000     269.000000  269.000000         269.000000
# mean     0.669145    2.959108  220465.747212    3.524164           2.672862
# std      0.471398    1.066012  140524.341051    1.436586           1.651788
# min      0.000000    1.000000  110008.000000    1.000000           1.000000
# 25%      0.000000    2.000000  122018.000000    3.000000           1.000000
# 50%      1.000000    3.000000  201303.000000    4.000000           2.000000
# 75%      1.000000    4.000000  201310.000000    5.000000           4.000000
# max      1.000000    5.000000  560037.000000    5.000000           5.000000
#
#        internet access      device  screen size          os     browser  ...  \
# count       269.000000  269.000000   269.000000  269.000000  269.000000  ...
# mean          3.260223    1.676580     4.282528    1.776952    1.275093  ...
# ...

# %%
df_cont_var = df1.loc[: ,(df1.dtypes == 'int64')]

# %%
# UDF to get descriptive stats summary for continuous variable
def continous_var_summary(x):
    return pd.Series([x.count(),x.sum(),x.min(),x.mean(),x.median(),x.std(),x.var(),x.quantile(0.01),x.quantile(0.05),x.quantile(0.1),
                    x.quantile(0.25),x.quantile(0.5),x.quantile(0.75),x.quantile(0.90),x.quantile(0.95),x.quantile(0.99),x.max()],
                    index = ['N','SUM','MIN','MEAN','MEDIAN','STD','VAR','P1','P5','P10','P25','P50','P75','P90','P95','P99','MAX'])

# %%
df_cont_var.apply(continous_var_summary).T.round(2)
# Out:
#                        N         SUM       MIN       MEAN    MEDIAN  \
# gender             269.0       180.0       0.0       0.67       1.0
# age                269.0       796.0       1.0       2.96       3.0
# pin                269.0  59305286.0  110008.0  220465.75  201303.0
# duration           269.0       948.0       1.0       3.52       4.0
# times of purchase  269.0       719.0       1.0       2.67       2.0
# internet access    269.0       877.0       2.0       3.26       3.0
# device             269.0       451.0       1.0       1.68       1.0
# screen size        269.0      1152.0       2.0       4.28       4.0
# os                 269.0       478.0       1.0       1.78       2.0
# browser            269.0       343.0       1.0       1.28       1.0
# channel            269.0       366.0       1.0       1.36       1.0
# reach              269.0       685.0       1.0       2.55       3.0
# time taken         269.0      1055.0       1.0       3.92       4.0
# ...

# %%
df1.nunique()
# Out:
# gender                2
# age                   5
# city                 11
# pin                  39
# duration              5
# times of purchase     5
# internet access       4
# device                4
# screen size           3
# os                    3
# browser               4
# channel               3
# reach                 4
# time taken            5
# payoption             3
# cart                  4
# shopping cart         5
# web content           4
# similar procuct       4
# info                  5
# info procuct          4
# navigation            4
# processing speed      5
# user freindly web     5
# pay method            3
# time trust            4
# empathy               4
# privacy               3
# communication         4
# benifit               5
# enjoyment             5
# flexibility           4
# return policy         3
# loyalty               5
# quality               3
# web quality           3
# net benifit           4
# trust                 5
# ...

# %%
df1["gender"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# 0 and 1 consider as male and famale

# %%
df1["age"].unique()
# Out:
# array([3, 2, 4, 1, 5], dtype=int64)

# %% [markdown]
# age group in between 30-40,20-30,40-50,10-20,50-60

# %%
df1["duration"].unique()
# Out:
# array([5, 4, 3, 1, 2], dtype=int64)

# %% [markdown]
# duration of purchase in year wise like 5yrs,4yrs,3yrs,1yr and 2 yrs

# %%
df1["times of purchase"].unique()
# Out:
# array([4, 5, 1, 2, 3], dtype=int64)

# %% [markdown]
# In this particular columns consist how many times purachase particular product from onlin market in past one year. [4 times,5times,1time,2time and 3 times]

# %%
df1["internet access"].unique()
# Out:
# array([4, 2, 3, 5], dtype=int64)

# %% [markdown]
# it consist choice of access internet while shoping online , it is consider as mobile internet,wifi,broadband,Dail-up

# %%
df1["device"].unique()
# Out:
# array([3, 1, 4, 2], dtype=int64)

# %% [markdown]
# it contain types of device used while purchasing. mobile phone,tablet,laptop,desktop

# %%
df1["screen size"].unique()
# Out:
# array([5, 2, 4], dtype=int64)

# %% [markdown]
# classified as large medium and small

# %%
df1["os"].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %% [markdown]
# also microsoft,macOS and Linux

# %%
df1["browser"].unique()
# Out:
# array([1, 2, 4, 3], dtype=int64)

# %% [markdown]
# mazilla firefox,google chrome,edge,internet explorer

# %%
df1["channel"].unique()
# Out:
# array([1, 3, 4], dtype=int64)

# %% [markdown]
# amazone,flipkart and social media

# %%
df1["reach"].unique()
# Out:
# array([1, 4, 3, 2], dtype=int64)

# %%
df1["time taken"].unique()
# Out:
# array([3, 5, 4, 2, 1], dtype=int64)

# %% [markdown]
# 3hr,5hr,4hr,2hr and 1 hr

# %%
df1["payoption"].unique()
# Out:
# array([4, 1, 2], dtype=int64)

# %% [markdown]
# cash on delivery,by card, EMI

# %%
df1["cart"].unique()
# Out:
# array([3, 5, 1, 4], dtype=int64)

# %%
df1["shopping cart"].unique()
# Out:
# array([3, 5, 2, 1, 4], dtype=int64)

# %%
for col in df1.columns:
    if print(df1[col].unique()):
        print()
# Out:
# [0 1]
# [3 2 4 1 5]
# ['Delhi' 'Greater Noida' 'Karnal ' 'Bangalore ' 'Noida' 'Solan'
#  'Moradabad' 'Gurgaon ' 'Merrut' 'Ghaziabad' 'Bulandshahr']
# [110009 110030 201308 132001 530068 110011 110018 173229 110039 244001
#  122018 201310 560037 203207 250001 201005 110044 201306 560010 201305
#  110042 132036 560018 110008 560002 201303 201312 203202 560001 201304
#  560003 110014 560013 173212 122009 201009 201008 201001 203001]
# [5 4 3 1 2]
# [4 5 1 2 3]
# [4 2 3 5]
# [3 1 4 2]
# [5 2 4]
# [1 3 2]
# [1 2 4 3]
# [1 3 4]
# [1 4 3 2]
# [3 5 4 2 1]
# [4 1 2]
# [3 5 1 4]
# [3 5 2 1 4]
# [4 5 1 3]
# [3 5 4 2]
# [3 5 4 2 1]
# [4 5 1 2]
# [4 5 1 2]
# [1 5 4 2 3]
# [2 5 4 1 3]
# [2 5 4]
# [2 5 4 3]
# [5 4 1 3]
# [4 5 3]
# [4 5 3 1]
# [3 5 4 1 2]
# [1 5 3 4 2]
# [2 5 3 4]
# [2 5 4]
# [4 5 3 2 1]
# [3 5 4]
# [5 4 2]
# [4 5 3 2]
# [5 4 1 2 3]
# [3 5 4 2]
# [3 5 4 2]
# [2 5 4 3]
# [3 4 5]
# [4 3 5 2 1]
# [4 3 5 1 2]
# [5 3 4 1 2]
# [4 5 3 1 2]
# [5 4 3]

# %%
#cleaning the data

# %%
df1.isnull().sum()
# Out:
# gender               0
# age                  0
# city                 0
# pin                  0
# duration             0
# times of purchase    0
# internet access      0
# device               0
# screen size          0
# os                   0
# browser              0
# channel              0
# reach                0
# time taken           0
# payoption            0
# cart                 0
# shopping cart        0
# web content          0
# similar procuct      0
# info                 0
# info procuct         0
# navigation           0
# processing speed     0
# user freindly web    0
# pay method           0
# time trust           0
# empathy              0
# privacy              0
# communication        0
# benifit              0
# enjoyment            0
# flexibility          0
# return policy        0
# loyalty              0
# quality              0
# web quality          0
# net benifit          0
# trust                0
# variety category     0
# provision            0
# ...

# %% [markdown]
# There is no missing v alue present in the columns

# %% [markdown]
# On the basis of case study we can drop some unnecessary columns. In study mention that Five major factors that contributed to
# the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and
# net benefit. Lets check each column whether it is necessary or not for customer retention.

# %%
df1.drop("pin",axis=1,inplace=True)

# %%
df1.drop("screen size",axis=1,inplace=True)

# %%
df1.drop("os",axis=1,inplace=True)

# %%
df1.drop("reach",axis=1,inplace=True)

# %%
df1.drop("shopping cart",axis=1,inplace=True)

# %%
# checking outliers

# %%
df1.boxplot(figsize=(25,15))
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
def outlier_IQR(data_frame,feature_name):
    IQR = data_frame[feature_name].quantile(0.75)-data_frame[feature_name].quantile(0.25)
    lower_bridge = data_frame[feature_name].quantile(0.25)-(IQR*1.5)
    upper_bridge = data_frame[feature_name].quantile(0.75)+(IQR*1.5)
    return (lower_bridge,upper_bridge)

# %%
sns.boxplot(df1["role"])
# Out:
# <AxesSubplot:xlabel='role'>

# %%
outlier_IQR(df1,"role")
# Out:
# (1.5, 5.5)

# %%
df[(df1.role<1.5)|(df1.role>5.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 4           NaN                      1                    2
# 7           NaN                      0                    4
# 16          NaN                      0                    3
# 20          NaN                      1                    2
# 21          NaN                      0                    3
# 30          NaN                      1                    1
# 35          NaN                      1                    2
# 38          NaN                      1                    4
# 49          NaN                      1                    3
# 52          NaN                      0                    4
# 53          NaN                      1                    4
# 64          NaN                      1                    4
# 65          NaN                      1                    5
# 70          NaN                      1                    2
# 79          NaN                      1                    3
# ...

# %%
sns.boxplot(df1["gratification"])
# Out:
# <AxesSubplot:xlabel='gratification'>

# %%
outlier_IQR(df1,"gratification")
# Out:
# (1.5, 5.5)

# %%
df[(df1.gratification<1.5)|(df1.gratification>5.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 7           NaN                      0                    4
# 21          NaN                      0                    3
# 38          NaN                      1                    4
# 52          NaN                      0                    4
# 53          NaN                      1                    4
# 64          NaN                      1                    4
# 65          NaN                      1                    5
# 70          NaN                      1                    2
# 110         NaN                      0                    4
# 131         NaN                      0                    4
# 143         NaN                      0                    4
# 156         NaN                      1                    4
# 157         NaN                      1                    5
# 158         NaN                      1                    2
# 231         NaN                      1                    4
# ...

# %%
sns.boxplot(df1["social status"])
# Out:
# <AxesSubplot:xlabel='social status'>

# %%
outlier_IQR(df1,"social status")
# Out:
# (1.5, 5.5)

# %%
sns.boxplot(df1["adventure"])
# Out:
# <AxesSubplot:xlabel='adventure'>

# %%
outlier_IQR(df1,"adventure")
# Out:
# (1.5, 5.5)

# %%
df[(df1.adventure<1.5)|(df1.adventure>5.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 88          NaN                      0                    2
# 112         NaN                      0                    3
# 133         NaN                      0                    3
# 196         NaN                      0                    2
# 207         NaN                      0                    2
#
#     3 Which city do you shop online from?  \
# 88                             Bangalore
# 112                           Bulandshahr
# 133                           Bulandshahr
# 196                            Bangalore
# 207                            Bangalore
#
#      4 What is the Pin Code of where you shop online from?  \
# 88                                              560013
# 112                                             203001
# 133                                             203001
# 196                                             560013
# 207                                             560013
#
# ...

# %%
sns.boxplot(df1["savings"])
# Out:
# <AxesSubplot:xlabel='savings'>

# %%
outlier_IQR(df1,"savings")
# Out:
# (2.5, 6.5)

# %%
df[(df1.savings<2.5)|(df1.savings>6.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 0           NaN                      0                    3
# 10          NaN                      0                    3
# 24          NaN                      1                    2
# 31          NaN                      0                    3
# 41          NaN                      0                    3
# 44          NaN                      1                    3
# 56          NaN                      0                    2
# 59          NaN                      1                    4
# 66          NaN                      0                    3
# 76          NaN                      0                    4
# 82          NaN                      0                    4
# 103         NaN                      1                    2
# 111         NaN                      0                    3
# 113         NaN                      0                    3
# 124         NaN                      1                    2
# ...

# %%
sns.boxplot(df1["provision"])
# Out:
# <AxesSubplot:xlabel='provision'>

# %%
outlier_IQR(df1,"provision")
# Out:
# (2.5, 6.5)

# %%
df[(df1.provision<2.5)|(df1.provision>6.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 88          NaN                      0                    2
# 112         NaN                      0                    3
# 133         NaN                      0                    3
# 196         NaN                      0                    2
# 207         NaN                      0                    2
#
#     3 Which city do you shop online from?  \
# 88                             Bangalore
# 112                           Bulandshahr
# 133                           Bulandshahr
# 196                            Bangalore
# 207                            Bangalore
#
#      4 What is the Pin Code of where you shop online from?  \
# 88                                              560013
# 112                                             203001
# 133                                             203001
# 196                                             560013
# 207                                             560013
#
# ...

# %%
sns.boxplot(df1["variety category"])
# Out:
# <AxesSubplot:xlabel='variety category'>

# %%
outlier_IQR(df1,"variety category")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["trust"])
# Out:
# <AxesSubplot:xlabel='trust'>

# %%
outlier_IQR(df1,"trust")
# Out:
# (2.5, 6.5)

# %%
df[(df1.trust<2.5)|(df1.trust>6.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 7           NaN                      0                    4
# 21          NaN                      0                    3
# 38          NaN                      1                    4
# 52          NaN                      0                    4
# 53          NaN                      1                    4
# 64          NaN                      1                    4
# 65          NaN                      1                    5
# 70          NaN                      1                    2
# 86          NaN                      0                    3
# 107         NaN                      1                    1
# 110         NaN                      0                    4
# 128         NaN                      1                    1
# 131         NaN                      0                    4
# 143         NaN                      0                    4
# 156         NaN                      1                    4
# ...

# %%
sns.boxplot(df1["net benifit"])
# Out:
# <AxesSubplot:xlabel='net benifit'>

# %%
outlier_IQR(df1,"net benifit")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["web quality"])
# Out:
# <AxesSubplot:xlabel='web quality'>

# %%
outlier_IQR(df1,"web quality")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["return policy"])
# Out:
# <AxesSubplot:xlabel='return policy'>

# %%
outlier_IQR(df1,"return policy")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["flexibility"])
# Out:
# <AxesSubplot:xlabel='flexibility'>

# %%
outlier_IQR(df1,"flexibility")
# Out:
# (2.5, 6.5)

# %%
df[(df1.flexibility<2.5)|(df1.flexibility>6.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 0           NaN                      0                    3
# 31          NaN                      0                    3
# 44          NaN                      1                    3
# 59          NaN                      1                    4
# 66          NaN                      0                    3
# 113         NaN                      0                    3
# 134         NaN                      0                    3
# 172         NaN                      1                    4
# 193         NaN                      0                    3
# 210         NaN                      1                    4
# 214         NaN                      0                    3
# 250         NaN                      0                    3
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 31                                  Noida
# 44                                 Merrut
# ...

# %%
sns.boxplot(df1["communication"])
# Out:
# <AxesSubplot:xlabel='communication'>

# %%
outlier_IQR(df1,"communication")
# Out:
# (2.5, 6.5)

# %%
df[(df1.communication<2.5)|(df1.communication>6.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 13          NaN                      1                    3
# 27          NaN                      0                    3
# 74          NaN                      1                    3
# 101         NaN                      1                    3
# 122         NaN                      1                    3
# 147         NaN                      1                    3
# 151         NaN                      1                    3
# 153         NaN                      1                    3
# 245         NaN                      1                    3
# 247         NaN                      1                    3
# 259         NaN                      1                    3
#
#     3 Which city do you shop online from?  \
# 13                          Greater Noida
# 27                                  Delhi
# 74                                Karnal
# 101                         Greater Noida
# ...

# %%
sns.boxplot(df1["empathy"])
# Out:
# <AxesSubplot:xlabel='empathy'>

# %%
outlier_IQR(df1,"empathy")
# Out:
# (2.5, 6.5)

# %%
df[(df1.empathy<2.5)|(df1.empathy>6.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 7           NaN                      0                    4
# 21          NaN                      0                    3
# 38          NaN                      1                    4
# 52          NaN                      0                    4
# 53          NaN                      1                    4
# 64          NaN                      1                    4
# 65          NaN                      1                    5
# 70          NaN                      1                    2
# 110         NaN                      0                    4
# 131         NaN                      0                    4
# 143         NaN                      0                    4
# 156         NaN                      1                    4
# 157         NaN                      1                    5
# 158         NaN                      1                    2
# 231         NaN                      1                    4
# ...

# %%
sns.boxplot(df1["time trust"])
# Out:
# <AxesSubplot:xlabel='time trust'>

# %%
outlier_IQR(df1,"time trust")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["pay method"])
# Out:
# <AxesSubplot:xlabel='pay method'>

# %%
outlier_IQR(df1,"pay method")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["user freindly web"])
# Out:
# <AxesSubplot:xlabel='user freindly web'>

# %%
outlier_IQR(df1,"user freindly web")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["processing speed"])
# Out:
# <AxesSubplot:xlabel='processing speed'>

# %%
outlier_IQR(df1,"processing speed")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["navigation"])
# Out:
# <AxesSubplot:xlabel='navigation'>

# %%
outlier_IQR(df1,"navigation")
# Out:
# (2.5, 6.5)

# %%
df[(df1.navigation<2.5)|(df1.navigation>6.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 7           NaN                      0                    4
# 21          NaN                      0                    3
# 38          NaN                      1                    4
# 52          NaN                      0                    4
# 53          NaN                      1                    4
# 64          NaN                      1                    4
# 65          NaN                      1                    5
# 70          NaN                      1                    2
# 88          NaN                      0                    2
# 110         NaN                      0                    4
# 112         NaN                      0                    3
# 131         NaN                      0                    4
# 133         NaN                      0                    3
# 143         NaN                      0                    4
# 156         NaN                      1                    4
# ...

# %%
sns.boxplot(df1["info procuct"])
# Out:
# <AxesSubplot:xlabel='info procuct'>

# %%
outlier_IQR(df1,"info procuct")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["similar procuct"])
# Out:
# <AxesSubplot:xlabel='similar procuct'>

# %%
outlier_IQR(df1,"similar procuct")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["web content"])
# Out:
# <AxesSubplot:xlabel='web content'>

# %%
outlier_IQR(df1,"web content")
# Out:
# (2.5, 6.5)

# %%
sns.boxplot(df1["cart"])
# Out:
# <AxesSubplot:xlabel='cart'>

# %%
outlier_IQR(df1,"cart")
# Out:
# (3.0, 3.0)

# %%
df[(df1.cart<3.0)|(df1.cart>3.0)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 1           NaN                      1                    2
# 3           NaN                      0                    2
# 4           NaN                      1                    2
# 5           NaN                      1                    3
# 15          NaN                      1                    2
# ..          ...                    ...                  ...
# 258         NaN                      1                    2
# 260         NaN                      1                    3
# 262         NaN                      1                    2
# 264         NaN                      1                    2
# 268         NaN                      1                    4
#
#     3 Which city do you shop online from?  \
# 1                                   Delhi
# 3                                 Karnal
# 4                              Bangalore
# 5                                   Noida
# ...

# %%
sns.boxplot(df1["payoption"])
# Out:
# <AxesSubplot:xlabel='payoption'>

# %%
outlier_IQR(df1,"payoption")
# Out:
# (-0.5, 3.5)

# %%
df[(df1.payoption<-0.5)|(df1.payoption>3.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 0           NaN                      0                    3
# 2           NaN                      1                    2
# 5           NaN                      1                    3
# 14          NaN                      1                    2
# 17          NaN                      0                    4
# 28          NaN                      1                    4
# 31          NaN                      0                    3
# 33          NaN                      1                    4
# 36          NaN                      0                    3
# 44          NaN                      1                    3
# 46          NaN                      0                    4
# 50          NaN                      1                    4
# 59          NaN                      1                    4
# 61          NaN                      0                    1
# 66          NaN                      0                    3
# ...

# %%
sns.boxplot(df1["channel"])
# Out:
# <AxesSubplot:xlabel='channel'>

# %%
outlier_IQR(df1,"channel")
# Out:
# (1.0, 1.0)

# %%
df[(df1.channel<1.0)|(df1.channel>1.0)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 4           NaN                      1                    2
# 6           NaN                      0                    4
# 16          NaN                      0                    3
# 18          NaN                      1                    4
# 20          NaN                      1                    2
# 30          NaN                      1                    1
# 35          NaN                      1                    2
# 37          NaN                      0                    4
# 49          NaN                      1                    3
# 51          NaN                      0                    5
# 79          NaN                      1                    3
# 82          NaN                      0                    4
# 88          NaN                      0                    2
# 89          NaN                      0                    2
# 95          NaN                      1                    2
# ...

# %%
sns.boxplot(df1["browser"])
# Out:
# <AxesSubplot:xlabel='browser'>

# %%
outlier_IQR(df1,"browser")
# Out:
# (1.0, 1.0)

# %%
df[(df1.browser<1.0)|(df1.browser>1.0)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 3           NaN                      0                    2
# 4           NaN                      1                    2
# 15          NaN                      1                    2
# 16          NaN                      0                    3
# 19          NaN                      1                    2
# 20          NaN                      1                    2
# 29          NaN                      1                    4
# 30          NaN                      1                    1
# 34          NaN                      1                    5
# 35          NaN                      1                    2
# 47          NaN                      0                    1
# 48          NaN                      1                    3
# 49          NaN                      1                    3
# 62          NaN                      0                    3
# 63          NaN                      1                    3
# ...

# %%
sns.boxplot(df1["device"])
# Out:
# <AxesSubplot:xlabel='device'>

# %%
outlier_IQR(df1,"device")
# Out:
# (-0.5, 3.5)

# %%
df[(df1.device<-0.5)|(df1.device>3.5)]
# Out:
#      Unnamed: 0  1Gender of respondent  2 How old are you?   \
# 6           NaN                      0                    4
# 21          NaN                      0                    3
# 22          NaN                      0                    4
# 37          NaN                      0                    4
# 51          NaN                      0                    5
# 89          NaN                      0                    2
# 109         NaN                      0                    4
# 130         NaN                      0                    4
# 140         NaN                      0                    4
# 191         NaN                      0                    2
# 229         NaN                      0                    2
# 253         NaN                      0                    4
#
#     3 Which city do you shop online from?  \
# 6                                   Delhi
# 21                               Gurgaon
# 22                          Greater Noida
# ...

# %% [markdown]
# THere are 26 columns has present outliers out of 47 and when we remove the outlier from each columns , we lost lots of data from
# our data set so I did not do anything about outlier.

# %%
# relationship analysis

# %%
cor=df1.corr()

# %%
plt.figure(figsize=(35,35))
sns.heatmap(cor,xticklabels = cor.columns,yticklabels = cor.columns,annot=True)
plt.show()

# %% [markdown]
# There are number of columns are equally correlated with each other . They are as follows:
#
# web content and similar product.
#
# patronizing and adventure.
#
# social status and gratification.
#
# info product and navigation.
#
# benifit and enjoyment.
#
# empathy and privacy. etc...

# %%
sns.countplot(df1["savings"])
# Out:
# <AxesSubplot:xlabel='savings', ylabel='count'>

# %%
sns.countplot(df1["return policy"])
# Out:
# <AxesSubplot:xlabel='return policy', ylabel='count'>

# %% [markdown]
# Return policy is the most impotant merits of onlile purchase system . It will increase the customer satisfaction and it drive to
# repurchasing mentality.

# %%
sns.countplot(df1["similar procuct"])
# Out:
# <AxesSubplot:xlabel='similar procuct', ylabel='count'>

# %% [markdown]
# Information on similar product to the one highlighted  is important for product comparison. It  is also increase the customer satisfaction. Here can see that increase the number of similer product will increase the satisfaction of customer.

# %%
sns.countplot(df1["web content"])
# Out:
# <AxesSubplot:xlabel='web content', ylabel='count'>

# %% [markdown]
# Web content is the one of the basic variable for increasing the tendancy of purachasing.

# %%
sns.countplot(df1["cart"])
# Out:
# <AxesSubplot:xlabel='cart', ylabel='count'>

# %% [markdown]
# In this column mention about cart system . Some people were cart their selected product for future. It might be because of comparison
# of similar product,changing the offers, availability of better product , future purchase or etc. Here we can consider thet most
# of the people cart their product for future purchasing.

# %%
sns.countplot(df1["payoption"])
# Out:
# <AxesSubplot:xlabel='payoption', ylabel='count'>

# %% [markdown]
# There are several type of option for payment cash for purchasing from online. People can select as their conveniet and some payment
# were not applicable for certain product. so here we can consider that most of the people choosen payment system as cash on delivery.
# The merit of the COD is they conform their product before paying the cash.

# %%
sns.countplot(df1["time taken"])
# Out:
# <AxesSubplot:xlabel='time taken', ylabel='count'>

# %% [markdown]
# This column mention about time taken for purchase decision. Here we can consider as hr wise so most of the people take 5 hr for purchasing
# perticular product, very least of the people taken 1 or 2 hr. It might be because of choice of similer product or high number of choice or other reason.

# %%
sns.countplot(df1["gender"])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# As I mentioned above 0 consider as men and 1 consider as female . Here we can clearly see that female is more attracted with online
# purchases.

# %%
sns.countplot(df1["age"])
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %% [markdown]
# Age between 20-30 & 30-40 are highly dependes in online purachase system. Age between 10-20 and above 50 are very less and equally depends in online system.

# %%
plt.figure(figsize=(12,8))
sns.countplot(df1["city"])
# Out:
# <AxesSubplot:xlabel='city', ylabel='count'>

# %% [markdown]
# Delhi is the location where highly belive in online system . And people were located in delhi more depends onlice trade system

# %%
sns.countplot(df1["duration"])
# Out:
# <AxesSubplot:xlabel='duration', ylabel='count'>

# %% [markdown]
# Here we can see that most of people who were used to online purachase system in last 5 yrs so we can learn that they are very satisfied
# with this system and repurchasing mentality also increase.

# %%
sns.countplot(df1["times of purchase"])
# Out:
# <AxesSubplot:xlabel='times of purchase', ylabel='count'>

# %% [markdown]
# In this we can learn that only 1 time people purachase in last 1 yr but above 45-60 people were purchased 4 and 5 times. so average
# of the people like to purchase online shopping.

# %%
sns.countplot(df1["internet access"])
# Out:
# <AxesSubplot:xlabel='internet access', ylabel='count'>

# %% [markdown]
# most of them are used access internet through mobile internet.

# %%
sns.countplot(df1["device"])
# Out:
# <AxesSubplot:xlabel='device', ylabel='count'>

# %% [markdown]
# Highest people used device for purchasing is mobile device and lowest device is desktop computer.

# %%
sns.countplot(df1["browser"])
# Out:
# <AxesSubplot:xlabel='browser', ylabel='count'>

# %% [markdown]
# most of the people were used google chrome for online shoping.

# %%
sns.countplot(df1["channel"])
# Out:
# <AxesSubplot:xlabel='channel', ylabel='count'>

# %% [markdown]
# will consider like as amazon(1),flipkart(3),snapdeal(4). so most of the people preferd amazon channel for purachasing.

# %%
sns.relplot(x="duration", y ="enjoyment",hue="gender",data=df1,kind='line')

# %% [markdown]
# In the case of female they are satisfaction(enjoyment) up and down proportion , then the case of male their enjoyment are down word slop
# in the life of online purchase

# %%
sns.scatterplot(x="payoption",y="savings",data=df1)
# Out:
# <AxesSubplot:xlabel='payoption', ylabel='savings'>

# %%
sns.catplot(x ="enjoyment", y ="value", hue ="times of purchase", data = df1,kind = 'bar')

# %% [markdown]
# Increasing the number of purchase shows that increase the level of enjoyment and value of spend money. It means the people are
# satisfied with online shoping.

# %%
sns.catplot(x='channel',y='value',hue='gender',data=df1,kind='violin')

# %% [markdown]
# we cosider that there are three channel for online purachase(amazone,flipkart,mintra) for this case study and in the case of female thay got more value
# from flipkart , in the same channel male do not get average money spend value. Male got from amazone amd mintra.

# %%
sns.relplot(x="net benifit", y ="quality",hue="channel",data=df1,kind='line')

# %% [markdown]
# In the case of  channel one increase the quality and net benifit both are interconnected , increase the quality of product will
# increase the net benifit. In the similar case channel four increase the quality will effect the net benifit but not that much like
# channel one and also when quality reached at the point of 4.0 the net benifit remain constant. In the case of channel three can't see any measurment about the channel.

# %%
sns.catplot(x='time trust',y='return policy',hue='channel',data=df1,kind='violin')

# %% [markdown]
# The main two features of online shoping is return ploicy and time trust (Trust that the online retail store will fulfill its part of the transaction at the stipulated time).
# here the case of three channel , channel four fullfill both features and channel three is fail to fulfill the features. so the repurchasing mentality
# of customer of channel three will dcrease and channel 4 will increase. And on the basis of advantages of features will increase satisfaction.

# %%
sns.catplot(x="similar procuct", y ="benifit",data=df1,kind='bar')

# %% [markdown]
# Benifit(monetory benifit and discount) and similar product(Information on similar product to the one highlighted  is important for product comparison).
# Another important feature of online system is information about similar product. Highlight the similar product and informatin will increase the monetory
# benifit at the stage of four and when reach the stage of five it was little bit reduced.

# %%
sns.catplot(x="info procuct", y ="benifit",data=df1,kind='bar')

# %% [markdown]
# Highlighting the deatails of information of product also increase the benifit of customer. Here product two bring more information
# about the product so benifit also increase.

# %%
sns.catplot(x="user freindly web", y ="privacy",data=df1,kind='bar')

# %% [markdown]
# user freindly web(User friendly Interface of the website) and privacy(Being able to guarantee the privacy of the customer) is main
# bedrock of a good online trade channel. Here providing better interface of the web or user freindly web wil drive the repurchasing
# mentality of customer through proper kwoledge about web. It also prottect from any error and fault so privary also increased through
# user freindly web.

# %%
sns.catplot(x='pay method',y='privacy',data=df1,kind='violin')

# %% [markdown]
# Here we can see thare are three method for payment 2,4 and 5. method 5 provide highly privacy to customer and method 4 provide privacy
# from the middle point. so more privacy and secured method is five.

# %%
sns.catplot(x='savings',y='trust',data=df1,kind='violin')

# %% [markdown]
# trust(User satisfaction cannot exist without trust) and saving(monetory savings)
#
# A good web provide trust to their customer and also save the money of the customer. Savings 5 get trust from begining to end

# %%
df1.columns
# Out:
# Index(['gender', 'age', 'city', 'duration', 'times of purchase',
#        'internet access', 'device', 'browser', 'channel', 'time taken',
#        'payoption', 'cart', 'web content', 'similar procuct', 'info',
#        'info procuct', 'navigation', 'processing speed', 'user freindly web',
#        'pay method', 'time trust', 'empathy', 'privacy', 'communication',
#        'benifit', 'enjoyment', 'flexibility', 'return policy', 'loyalty',
#        'quality', 'web quality', 'net benifit', 'trust', 'variety category',
#        'provision', 'savings', 'patronizing', 'adventure', 'social status',
#        'gratification', 'role', 'value'],
#       dtype='object')

# %%
df1.shape
# Out:
# (269, 42)

# %% [markdown]
# # conclusion:

# %% [markdown]
# The purpose of the research of the dataset(customer_retention) is finding the variable which drive the repeat purchase intention and customer
# satisfaction. After the analysis of the dataset I can understand both purchase retention and customer satisfaction are the same
# meaning. Satisfied customer should try to repurchase from online trade.
#
# After analysis the dataset most related feature for repurchasing are device of the customer,channel, payment option, providing fecilities like (cart,payment method
# user freindly web, quality, privacy etc.) etc.
